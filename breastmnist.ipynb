# %%
# Load and display a 224x224 BreastMNIST image

from medmnist import BreastMNIST
from torchvision import transforms
import matplotlib.pyplot as plt

# Download the dataset if not present and load one sample
dataset = BreastMNIST(split="test", download=True, size=224)
image, _ = dataset[120]  # image is a PIL image

# Display
plt.imshow(image, cmap="gray")
plt.axis("off")
plt.show()

# %%
_
