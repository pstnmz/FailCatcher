# %%
import pickle

pkl_path = "/mnt/data/psteinmetz/computer_vision_code/code/UQ_Toolbox/old_shap_results_calibration_breastmnist.pkl"

with open(pkl_path, "rb") as f:
    shap_results = pickle.load(f)

print("Loaded object type:", type(shap_results))
if isinstance(shap_results, dict):
    print("Dict key sample:", list(shap_results.keys())[:10])

# %%
shap_results['shap_values_folds'][0]
breakpoint()
